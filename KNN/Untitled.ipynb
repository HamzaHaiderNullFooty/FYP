# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from nltk.stem import PorterStemmer
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score
import os
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
dataset = pd.read_csv('classifier_data_0.csv', header = 0, encoding= 'utf-8')

dataset.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9', 'Unnamed: 10'], axis=1, inplace = True)
dataset.fillna("0", inplace = True)

owner_list = dataset["owner"].tolist()
#print(owner_list)
description_list = dataset["description"].tolist()
#print(description_list)

# %%
classes= list(set(owner_list))
print(classes)
# Out:
# ['iannucci@chromium.org', 'jamiewa...@chromium.org', 'hamaji@chromium.org', 'wangxianzhu@chromium.org', 'mferreria@chromium.org', 'sugoi@chromium.org', 'oleg@chromium.org', 'jbates@chromium.org', 'kristianm@chromium.org', 'rniwa@chromium.org', 'sbasi@chromium.org', 'tasak@chromium.org', 'kush...@gmail.com', 'mihaip@chromium.org', 'davemoore@chromium.org', 'qyears...@chromium.org', 'f...@opera.com', 'cmasone@chromium.org', 'jeremycho@chromium.org', 'haitaol@chromium.org', 'evan@chromium.org', 'rous...@chromium.org', 'bsimonnet@chromium.org', 'feng@chromium.org', 'deepakg@chromium.org', 'mpear...@chromium.org', 'meacer@chromium.org', 'sque@chromium.org', 'benrg@chromium.org', 'sky@chromium.org', 'hirosh...@chromium.org', 'bryeung@chromium.org', 'noamsml@chromium.org', 'cbentzel@chromium.org', 'r...@chromium.org', 'ahutter@chromium.org', 'morrita@chromium.org', 'jeremy@chromium.org', 'rpaquay@chromium.org', 'ups@chromium.org', 'mcgrathr@chromium.org', 'pam@chromium.org', 'uttam.ga...@sy
# ...

# %%
print(dataset.owner)
# Out:
# 0           amit@chromium.org
# 1            jon@chromium.org
# 2       pfeldman@chromium.org
# 3            jon@chromium.org
# 4       pkasting@chromium.org
#                 ...
# 4995                        0
# 4996                        0
# 4997                        0
# 4998                        0
# 4999                        0
# Name: owner, Length: 5000, dtype: object

# %%
print(dataset.description)
# Out:
# 0       Product Version      : <see about:version>URLs...
# 1       Product Version      : 0.2.149.27 (1583)URLs (...
# 2       Product Version      : chrome beta 1URLs (if a...
# 3       Product Version      : 0.2.149.27 (1583)URLs (...
# 4       Product Version      : 0.2.149.27URLs (if appl...
#                               ...
# 4995    product version       0214927 see aboutversion...
# 4996    product version     atlassian confluence 280 t...
# 4997    product version       see aboutversionurls if ...
# 4998    product version     atlassian confluence 280 t...
# 4999    product version       see aboutversionurls if ...
# Name: description, Length: 5000, dtype: object

# %%
target = np.array(classes)

# %%
print(dataset.shape)
# Out:
# (5000, 2)

# %%
print(target.shape)
# Out:
# (800,)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.description, dataset.owner, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
le = LabelEncoder()
le.fit_transform(X_train)

#Train the model using the training sets
knn.fit(y_train, le)

#Predict the response for test dataset
y_pred = knn.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-43bd3887d3ff> in <module>
#       7
#       8 #Train the model using the training sets
# ----> 9 knn.fit(y_train, le)
#      10
#      11 #Predict the response for test dataset
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1128         """
#    1129         if not isinstance(X, (KDTree, BallTree)):
# -> 1130             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1131
#    1132         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
pd.get_dummies(dataset.description)
# Out:
#          \
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 4995  0
# 4996  0
# 4997  0
# 4998  0
# 4999  0
#
#             'out/%s/Chromium.app/Contents/MacOS/Chromium' % mode,needs to be added to FindChrome().   \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4995                                                  0
# 4996                                                  0
# 4997                                                  0
# 4998                                                  0
# 4999                                                  0
#
# ...
